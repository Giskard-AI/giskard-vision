# %%
from giskard_vision.landmark_detection.dataloaders.loaders import DataLoaderFFHQ

dl = DataLoaderFFHQ("../datasets/ffhq")

# %%
image, marks, meta = dl[8]
image, marks, meta = image[0], marks[0], meta[0]
from giskard_vision.landmark_detection.visualisation.draw import draw_marks

draw_marks(image, [marks], ["green"])
# Out:
# <PIL.Image.Image image mode=RGB size=1024x1024>

# %%
for _, _, meta in dl:
    print(meta[0].get())
# Out:
# {'faceId': '866db6af-66ee-4828-b565-994f42571d2f', 'faceRectangle_top': 42, 'faceRectangle_left': 32, 'faceRectangle_width': 63, 'faceRectangle_height': 63, 'faceAttributes_smile': 0.003, 'faceAttributes_headPose_pitch': 5.4, 'faceAttributes_headPose_roll': 1.5, 'faceAttributes_headPose_yaw': 15.3, 'faceAttributes_gender': 'female', 'faceAttributes_age': 0.0, 'faceAttributes_facialHair_moustache': 0.0, 'faceAttributes_facialHair_beard': 0.0, 'faceAttributes_facialHair_sideburns': 0.0, 'faceAttributes_glasses': 'NoGlasses', 'faceAttributes_emotion_anger': 0.0, 'faceAttributes_emotion_contempt': 0.0, 'faceAttributes_emotion_disgust': 0.0, 'faceAttributes_emotion_fear': 0.0, 'faceAttributes_emotion_happiness': 0.003, 'faceAttributes_emotion_neutral': 0.993, 'faceAttributes_emotion_sadness': 0.003, 'faceAttributes_emotion_surprise': 0.0, 'faceAttributes_blur_blurLevel': 'medium', 'faceAttributes_blur_value': 0.55, 'faceAttributes_exposure_exposureLevel': 'goodExposure', 'faceAttributes_exposure_value': 0.6, 'faceAttributes_noise_noiseLevel': 'medium', 'faceAttributes_noise_value': 0.44, 'faceAttributes_makeup_eyeMakeup': False, 'faceAttributes_makeup_lipMakeup': False, 'faceAttributes_occlusion_foreheadOccluded': False, 'faceAttributes_occlusion_eyeOccluded': False, 'faceAttributes_occlusion_mouthOccluded': False, 'faceAttributes_hair_bald': 0.07, 'faceAttributes_hair_invisible': False, 'faceAttributes_hair_hairColor_0_color': 'brown', 'faceAttributes_hair_hairColor_0_confidence': 0.93, 'faceAttributes_hair_hairColor_1_color': 'blond', 'faceAttributes_hair_hairColor_1_confidence': 0.8, 'faceAttributes_hair_hairColor_2_color': 'black', 'faceAttributes_hair_hairColor_2_confidence': 0.41, 'faceAttributes_hair_hairColor_3_color': 'red', 'faceAttributes_hair_hairColor_3_confidence': 0.28, 'faceAttributes_hair_hairColor_4_color': 'gray', 'faceAttributes_hair_hairColor_4_confidence': 0.22, 'faceAttributes_hair_hairColor_5_color': 'other', 'faceAttributes_hair_hairColor_5_confidence': 0.2}
# {'faceId': '1bbcb21e-681e-46de-a079-c6a29000e99a', 'faceRectangle_top': 40, 'faceRectangle_left': 25, 'faceRectangle_width': 76, 'faceRectangle_height': 76, 'faceAttributes_smile': 1.0, 'faceAttributes_headPose_pitch': -7.3, 'faceAttributes_headPose_roll': -0.8, 'faceAttributes_headPose_yaw': -0.3, 'faceAttributes_gender': 'female', 'faceAttributes_age': 26.0, 'faceAttributes_facialHair_moustache': 0.0, 'faceAttributes_facialHair_beard': 0.0, 'faceAttributes_facialHair_sideburns': 0.0, 'faceAttributes_glasses': 'NoGlasses', 'faceAttributes_emotion_anger': 0.0, 'faceAttributes_emotion_contempt': 0.0, 'faceAttributes_emotion_disgust': 0.0, 'faceAttributes_emotion_fear': 0.0, 'faceAttributes_emotion_happiness': 1.0, 'faceAttributes_emotion_neutral': 0.0, 'faceAttributes_emotion_sadness': 0.0, 'faceAttributes_emotion_surprise': 0.0, 'faceAttributes_blur_blurLevel': 'low', 'faceAttributes_blur_value': 0.0, 'faceAttributes_exposure_exposureLevel': 'goodExposure', 'faceAttributes_exposure_value': 0.62, 'faceAttributes_noise_noiseLevel': 'low', 'faceAttributes_noise_value': 0.0, 'faceAttributes_makeup_eyeMakeup': True, 'faceAttributes_makeup_lipMakeup': False, 'faceAttributes_occlusion_foreheadOccluded': False, 'faceAttributes_occlusion_eyeOccluded': False, 'faceAttributes_occlusion_mouthOccluded': False, 'faceAttributes_hair_bald': 0.11, 'faceAttributes_hair_invisible': False, 'faceAttributes_hair_hairColor_0_color': 'blond', 'faceAttributes_hair_hairColor_0_confidence': 0.97, 'faceAttributes_hair_hairColor_1_color': 'brown', 'faceAttributes_hair_hairColor_1_confidence': 0.95, 'faceAttributes_hair_hairColor_2_color': 'red', 'faceAttributes_hair_hairColor_2_confidence': 0.65, 'faceAttributes_hair_hairColor_3_color': 'gray', 'faceAttributes_hair_hairColor_3_confidence': 0.3, 'faceAttributes_hair_hairColor_4_color': 'other', 'faceAttributes_hair_hairColor_4_confidence': 0.11, 'faceAttributes_hair_hairColor_5_color': 'black', 'faceAttributes_hair_hairColor_5_confidence': 0.02}
# {'faceId': '94430b4a-f659-47b1-8846-402f18624add', 'faceRectangle_top': 40, 'faceRectangle_left': 30, 'faceRectangle_width': 68, 'faceRectangle_height': 68, 'faceAttributes_smile': 0.002, 'faceAttributes_headPose_pitch': -4.6, 'faceAttributes_headPose_roll': 2.4, 'faceAttributes_headPose_yaw': 6.1, 'faceAttributes_gender': 'female', 'faceAttributes_age': 24.0, 'faceAttributes_facialHair_moustache': 0.0, 'faceAttributes_facialHair_beard': 0.0, 'faceAttributes_facialHair_sideburns': 0.0, 'faceAttributes_glasses': 'NoGlasses', 'faceAttributes_emotion_anger': 0.002, 'faceAttributes_emotion_contempt': 0.109, 'faceAttributes_emotion_disgust': 0.0, 'faceAttributes_emotion_fear': 0.0, 'faceAttributes_emotion_happiness': 0.002, 'faceAttributes_emotion_neutral': 0.874, 'faceAttributes_emotion_sadness': 0.013, 'faceAttributes_emotion_surprise': 0.0, 'faceAttributes_blur_blurLevel': 'low', 'faceAttributes_blur_value': 0.07, 'faceAttributes_exposure_exposureLevel': 'goodExposure', 'faceAttributes_exposure_value': 0.71, 'faceAttributes_noise_noiseLevel': 'low', 'faceAttributes_noise_value': 0.0, 'faceAttributes_makeup_eyeMakeup': False, 'faceAttributes_makeup_lipMakeup': False, 'faceAttributes_occlusion_foreheadOccluded': False, 'faceAttributes_occlusion_eyeOccluded': False, 'faceAttributes_occlusion_mouthOccluded': False, 'faceAttributes_hair_bald': 0.18, 'faceAttributes_hair_invisible': False, 'faceAttributes_hair_hairColor_0_color': 'brown', 'faceAttributes_hair_hairColor_0_confidence': 0.92, 'faceAttributes_hair_hairColor_1_color': 'black', 'faceAttributes_hair_hairColor_1_confidence': 0.76, 'faceAttributes_hair_hairColor_2_color': 'red', 'faceAttributes_hair_hairColor_2_confidence': 0.47, 'faceAttributes_hair_hairColor_3_color': 'other', 'faceAttributes_hair_hairColor_3_confidence': 0.34, 'faceAttributes_hair_hairColor_4_color': 'blond', 'faceAttributes_hair_hairColor_4_confidence': 0.2, 'faceAttributes_hair_hairColor_5_color': 'gray', 'faceAttributes_hair_hairColor_5_confidence': 0.2}
# {'faceId': '276b317f-f7cb-4a0d-ba79-e1949dc6d172', 'faceRectangle_top': 41, 'faceRectangle_left': 28, 'faceRectangle_width': 71, 'faceRectangle_height': 71, 'faceAttributes_smile': 0.0, 'faceAttributes_headPose_pitch': -2.4, 'faceAttributes_headPose_roll': 0.9, 'faceAttributes_headPose_yaw': 4.1, 'faceAttributes_gender': 'female', 'faceAttributes_age': 1.0, 'faceAttributes_facialHair_moustache': 0.0, 'faceAttributes_facialHair_beard': 0.0, 'faceAttributes_facialHair_sideburns': 0.0, 'faceAttributes_glasses': 'NoGlasses', 'faceAttributes_emotion_anger': 0.0, 'faceAttributes_emotion_contempt': 0.0, 'faceAttributes_emotion_disgust': 0.0, 'faceAttributes_emotion_fear': 0.0, 'faceAttributes_emotion_happiness': 0.0, 'faceAttributes_emotion_neutral': 0.572, 'faceAttributes_emotion_sadness': 0.0, 'faceAttributes_emotion_surprise': 0.427, 'faceAttributes_blur_blurLevel': 'low', 'faceAttributes_blur_value': 0.17, 'faceAttributes_exposure_exposureLevel': 'goodExposure', 'faceAttributes_exposure_value': 0.64, 'faceAttributes_noise_noiseLevel': 'low', 'faceAttributes_noise_value': 0.0, 'faceAttributes_makeup_eyeMakeup': False, 'faceAttributes_makeup_lipMakeup': False, 'faceAttributes_occlusion_foreheadOccluded': False, 'faceAttributes_occlusion_eyeOccluded': False, 'faceAttributes_occlusion_mouthOccluded': False, 'faceAttributes_hair_bald': 0.06, 'faceAttributes_hair_invisible': False, 'faceAttributes_hair_hairColor_0_color': 'black', 'faceAttributes_hair_hairColor_0_confidence': 0.96, 'faceAttributes_hair_hairColor_1_color': 'brown', 'faceAttributes_hair_hairColor_1_confidence': 0.94, 'faceAttributes_hair_hairColor_2_color': 'gray', 'faceAttributes_hair_hairColor_2_confidence': 0.3, 'faceAttributes_hair_hairColor_3_color': 'other', 'faceAttributes_hair_hairColor_3_confidence': 0.23, 'faceAttributes_hair_hairColor_4_color': 'blond', 'faceAttributes_hair_hairColor_4_confidence': 0.22, 'faceAttributes_hair_hairColor_5_color': 'red', 'faceAttributes_hair_hairColor_5_confidence': 0.07}
# {'faceId': 'aa77125d-ea71-43a5-9e6c-656e0d512127', 'faceRectangle_top': 40, 'faceRectangle_left': 26, 'faceRectangle_width': 74, 'faceRectangle_height': 74, 'faceAttributes_smile': 0.002, 'faceAttributes_headPose_pitch': -7.7, 'faceAttributes_headPose_roll': 0.0, 'faceAttributes_headPose_yaw': -4.5, 'faceAttributes_gender': 'female', 'faceAttributes_age': 28.0, 'faceAttributes_facialHair_moustache': 0.0, 'faceAttributes_facialHair_beard': 0.0, 'faceAttributes_facialHair_sideburns': 0.0, 'faceAttributes_glasses': 'NoGlasses', 'faceAttributes_emotion_anger': 0.0, 'faceAttributes_emotion_contempt': 0.0, 'faceAttributes_emotion_disgust': 0.0, 'faceAttributes_emotion_fear': 0.0, 'faceAttributes_emotion_happiness': 0.002, 'faceAttributes_emotion_neutral': 0.946, 'faceAttributes_emotion_sadness': 0.006, 'faceAttributes_emotion_surprise': 0.045, 'faceAttributes_blur_blurLevel': 'low', 'faceAttributes_blur_value': 0.0, 'faceAttributes_exposure_exposureLevel': 'goodExposure', 'faceAttributes_exposure_value': 0.6, 'faceAttributes_noise_noiseLevel': 'low', 'faceAttributes_noise_value': 0.29, 'faceAttributes_makeup_eyeMakeup': True, 'faceAttributes_makeup_lipMakeup': True, 'faceAttributes_occlusion_foreheadOccluded': False, 'faceAttributes_occlusion_eyeOccluded': False, 'faceAttributes_occlusion_mouthOccluded': False, 'faceAttributes_hair_bald': 0.2, 'faceAttributes_hair_invisible': False, 'faceAttributes_hair_hairColor_0_color': 'black', 'faceAttributes_hair_hairColor_0_confidence': 0.89, 'faceAttributes_hair_hairColor_1_color': 'brown', 'faceAttributes_hair_hairColor_1_confidence': 0.85, 'faceAttributes_hair_hairColor_2_color': 'blond', 'faceAttributes_hair_hairColor_2_confidence': 0.55, 'faceAttributes_hair_hairColor_3_color': 'gray', 'faceAttributes_hair_hairColor_3_confidence': 0.39, 'faceAttributes_hair_hairColor_4_color': 'other', 'faceAttributes_hair_hairColor_4_confidence': 0.26, 'faceAttributes_hair_hairColor_5_color': 'red', 'faceAttributes_hair_hairColor_5_confidence': 0.07}
# {'faceId': 'af9dd2e7-a08e-46b9-a9d2-c1d5f0e5eaf4', 'faceRectangle_top': 43, 'faceRectangle_left': 37, 'faceRectangle_width': 57, 'faceRectangle_height': 57, 'faceAttributes_smile': 0.0, 'faceAttributes_headPose_pitch': 5.6, 'faceAttributes_headPose_roll': -2.4, 'faceAttributes_headPose_yaw': 4.4, 'faceAttributes_gender': 'male', 'faceAttributes_age': 40.0, 'faceAttributes_facialHair_moustache': 0.1, 'faceAttributes_facialHair_beard': 0.1, 'faceAttributes_facialHair_sideburns': 0.1, 'faceAttributes_glasses': 'ReadingGlasses', 'faceAttributes_emotion_anger': 0.003, 'faceAttributes_emotion_contempt': 0.001, 'faceAttributes_emotion_disgust': 0.0, 'faceAttributes_emotion_fear': 0.0, 'faceAttributes_emotion_happiness': 0.0, 'faceAttributes_emotion_neutral': 0.986, 'faceAttributes_emotion_sadness': 0.009, 'faceAttributes_emotion_surprise': 0.0, 'faceAttributes_blur_blurLevel': 'low', 'faceAttributes_blur_value': 0.03, 'faceAttributes_exposure_exposureLevel': 'goodExposure', 'faceAttributes_exposure_value': 0.63, 'faceAttributes_noise_noiseLevel': 'low', 'faceAttributes_noise_value': 0.0, 'faceAttributes_makeup_eyeMakeup': False, 'faceAttributes_makeup_lipMakeup': False, 'faceAttributes_accessories_0_type': 'glasses', 'faceAttributes_accessories_0_confidence': 0.99, 'faceAttributes_occlusion_foreheadOccluded': False, 'faceAttributes_occlusion_eyeOccluded': False, 'faceAttributes_occlusion_mouthOccluded': True, 'faceAttributes_hair_bald': 0.09, 'faceAttributes_hair_invisible': False, 'faceAttributes_hair_hairColor_0_color': 'brown', 'faceAttributes_hair_hairColor_0_confidence': 0.99, 'faceAttributes_hair_hairColor_1_color': 'blond', 'faceAttributes_hair_hairColor_1_confidence': 0.57, 'faceAttributes_hair_hairColor_2_color': 'gray', 'faceAttributes_hair_hairColor_2_confidence': 0.36, 'faceAttributes_hair_hairColor_3_color': 'black', 'faceAttributes_hair_hairColor_3_confidence': 0.32, 'faceAttributes_hair_hairColor_4_color': 'red', 'faceAttributes_hair_hairColor_4_confidence': 0.22, 'faceAttributes_hair_hairColor_5_color': 'other', 'faceAttributes_hair_hairColor_5_confidence': 0.05}
# {'faceId': '737e349f-2d6c-4338-b134-1bb0bdbedb52', 'faceRectangle_top': 39, 'faceRectangle_left': 22, 'faceRectangle_width': 77, 'faceRectangle_height': 77, 'faceAttributes_smile': 1.0, 'faceAttributes_headPose_pitch': -8.4, 'faceAttributes_headPose_roll': 3.4, 'faceAttributes_headPose_yaw': -25.8, 'faceAttributes_gender': 'female', 'faceAttributes_age': 22.0, 'faceAttributes_facialHair_moustache': 0.0, 'faceAttributes_facialHair_beard': 0.0, 'faceAttributes_facialHair_sideburns': 0.0, 'faceAttributes_glasses': 'NoGlasses', 'faceAttributes_emotion_anger': 0.0, 'faceAttributes_emotion_contempt': 0.0, 'faceAttributes_emotion_disgust': 0.0, 'faceAttributes_emotion_fear': 0.0, 'faceAttributes_emotion_happiness': 1.0, 'faceAttributes_emotion_neutral': 0.0, 'faceAttributes_emotion_sadness': 0.0, 'faceAttributes_emotion_surprise': 0.0, 'faceAttributes_blur_blurLevel': 'low', 'faceAttributes_blur_value': 0.16, 'faceAttributes_exposure_exposureLevel': 'overExposure', 'faceAttributes_exposure_value': 0.97, 'faceAttributes_noise_noiseLevel': 'low', 'faceAttributes_noise_value': 0.0, 'faceAttributes_makeup_eyeMakeup': True, 'faceAttributes_makeup_lipMakeup': True, 'faceAttributes_occlusion_foreheadOccluded': False, 'faceAttributes_occlusion_eyeOccluded': False, 'faceAttributes_occlusion_mouthOccluded': False, 'faceAttributes_hair_bald': 0.08, 'faceAttributes_hair_invisible': False, 'faceAttributes_hair_hairColor_0_color': 'blond', 'faceAttributes_hair_hairColor_0_confidence': 0.96, 'faceAttributes_hair_hairColor_1_color': 'brown', 'faceAttributes_hair_hairColor_1_confidence': 0.76, 'faceAttributes_hair_hairColor_2_color': 'red', 'faceAttributes_hair_hairColor_2_confidence': 0.71, 'faceAttributes_hair_hairColor_3_color': 'other', 'faceAttributes_hair_hairColor_3_confidence': 0.35, 'faceAttributes_hair_hairColor_4_color': 'black', 'faceAttributes_hair_hairColor_4_confidence': 0.1, 'faceAttributes_hair_hairColor_5_color': 'gray', 'faceAttributes_hair_hairColor_5_confidence': 0.09}
# {'faceId': 'e0097b3f-41d4-4c76-8d52-80d1627094d5', 'faceRectangle_top': 41, 'faceRectangle_left': 29, 'faceRectangle_width': 69, 'faceRectangle_height': 69, 'faceAttributes_smile': 0.99, 'faceAttributes_headPose_pitch': -19.0, 'faceAttributes_headPose_roll': 3.2, 'faceAttributes_headPose_yaw': 9.4, 'faceAttributes_gender': 'female', 'faceAttributes_age': 4.0, 'faceAttributes_facialHair_moustache': 0.0, 'faceAttributes_facialHair_beard': 0.0, 'faceAttributes_facialHair_sideburns': 0.0, 'faceAttributes_glasses': 'NoGlasses', 'faceAttributes_emotion_anger': 0.0, 'faceAttributes_emotion_contempt': 0.0, 'faceAttributes_emotion_disgust': 0.0, 'faceAttributes_emotion_fear': 0.0, 'faceAttributes_emotion_happiness': 0.99, 'faceAttributes_emotion_neutral': 0.01, 'faceAttributes_emotion_sadness': 0.0, 'faceAttributes_emotion_surprise': 0.0, 'faceAttributes_blur_blurLevel': 'low', 'faceAttributes_blur_value': 0.06, 'faceAttributes_exposure_exposureLevel': 'goodExposure', 'faceAttributes_exposure_value': 0.58, 'faceAttributes_noise_noiseLevel': 'low', 'faceAttributes_noise_value': 0.0, 'faceAttributes_makeup_eyeMakeup': False, 'faceAttributes_makeup_lipMakeup': False, 'faceAttributes_occlusion_foreheadOccluded': False, 'faceAttributes_occlusion_eyeOccluded': False, 'faceAttributes_occlusion_mouthOccluded': False, 'faceAttributes_hair_bald': 0.07, 'faceAttributes_hair_invisible': False, 'faceAttributes_hair_hairColor_0_color': 'brown', 'faceAttributes_hair_hairColor_0_confidence': 0.99, 'faceAttributes_hair_hairColor_1_color': 'black', 'faceAttributes_hair_hairColor_1_confidence': 0.81, 'faceAttributes_hair_hairColor_2_color': 'blond', 'faceAttributes_hair_hairColor_2_confidence': 0.29, 'faceAttributes_hair_hairColor_3_color': 'red', 'faceAttributes_hair_hairColor_3_confidence': 0.2, 'faceAttributes_hair_hairColor_4_color': 'gray', 'faceAttributes_hair_hairColor_4_confidence': 0.18, 'faceAttributes_hair_hairColor_5_color': 'other', 'faceAttributes_hair_hairColor_5_confidence': 0.13}
# {'faceId': '4dae455a-987e-4246-8ec1-4f585ed0cfbe', 'faceRectangle_top': 42, 'faceRectangle_left': 29, 'faceRectangle_width': 71, 'faceRectangle_height': 71, 'faceAttributes_smile': 0.992, 'faceAttributes_headPose_pitch': -13.4, 'faceAttributes_headPose_roll': -2.8, 'faceAttributes_headPose_yaw': 4.5, 'faceAttributes_gender': 'female', 'faceAttributes_age': 32.0, 'faceAttributes_facialHair_moustache': 0.0, 'faceAttributes_facialHair_beard': 0.0, 'faceAttributes_facialHair_sideburns': 0.0, 'faceAttributes_glasses': 'NoGlasses', 'faceAttributes_emotion_anger': 0.0, 'faceAttributes_emotion_contempt': 0.0, 'faceAttributes_emotion_disgust': 0.0, 'faceAttributes_emotion_fear': 0.0, 'faceAttributes_emotion_happiness': 0.992, 'faceAttributes_emotion_neutral': 0.008, 'faceAttributes_emotion_sadness': 0.0, 'faceAttributes_emotion_surprise': 0.0, 'faceAttributes_blur_blurLevel': 'low', 'faceAttributes_blur_value': 0.0, 'faceAttributes_exposure_exposureLevel': 'goodExposure', 'faceAttributes_exposure_value': 0.4, 'faceAttributes_noise_noiseLevel': 'low', 'faceAttributes_noise_value': 0.0, 'faceAttributes_makeup_eyeMakeup': True, 'faceAttributes_makeup_lipMakeup': True, 'faceAttributes_occlusion_foreheadOccluded': False, 'faceAttributes_occlusion_eyeOccluded': False, 'faceAttributes_occlusion_mouthOccluded': False, 'faceAttributes_hair_bald': 0.02, 'faceAttributes_hair_invisible': False, 'faceAttributes_hair_hairColor_0_color': 'black', 'faceAttributes_hair_hairColor_0_confidence': 0.96, 'faceAttributes_hair_hairColor_1_color': 'brown', 'faceAttributes_hair_hairColor_1_confidence': 0.85, 'faceAttributes_hair_hairColor_2_color': 'gray', 'faceAttributes_hair_hairColor_2_confidence': 0.47, 'faceAttributes_hair_hairColor_3_color': 'other', 'faceAttributes_hair_hairColor_3_confidence': 0.29, 'faceAttributes_hair_hairColor_4_color': 'blond', 'faceAttributes_hair_hairColor_4_confidence': 0.23, 'faceAttributes_hair_hairColor_5_color': 'red', 'faceAttributes_hair_hairColor_5_confidence': 0.06}
# {'faceId': 'd22d7c54-22ce-4ec9-937e-fd2c1f28a38d', 'faceRectangle_top': 37, 'faceRectangle_left': 28, 'faceRectangle_width': 75, 'faceRectangle_height': 75, 'faceAttributes_smile': 0.994, 'faceAttributes_headPose_pitch': 11.6, 'faceAttributes_headPose_roll': 1.5, 'faceAttributes_headPose_yaw': 25.8, 'faceAttributes_gender': 'male', 'faceAttributes_age': 26.0, 'faceAttributes_facialHair_moustache': 0.1, 'faceAttributes_facialHair_beard': 0.1, 'faceAttributes_facialHair_sideburns': 0.1, 'faceAttributes_glasses': 'ReadingGlasses', 'faceAttributes_emotion_anger': 0.0, 'faceAttributes_emotion_contempt': 0.005, 'faceAttributes_emotion_disgust': 0.0, 'faceAttributes_emotion_fear': 0.0, 'faceAttributes_emotion_happiness': 0.994, 'faceAttributes_emotion_neutral': 0.001, 'faceAttributes_emotion_sadness': 0.0, 'faceAttributes_emotion_surprise': 0.0, 'faceAttributes_blur_blurLevel': 'low', 'faceAttributes_blur_value': 0.07, 'faceAttributes_exposure_exposureLevel': 'overExposure', 'faceAttributes_exposure_value': 0.8, 'faceAttributes_noise_noiseLevel': 'low', 'faceAttributes_noise_value': 0.0, 'faceAttributes_makeup_eyeMakeup': False, 'faceAttributes_makeup_lipMakeup': False, 'faceAttributes_accessories_0_type': 'glasses', 'faceAttributes_accessories_0_confidence': 0.99, 'faceAttributes_occlusion_foreheadOccluded': False, 'faceAttributes_occlusion_eyeOccluded': False, 'faceAttributes_occlusion_mouthOccluded': False, 'faceAttributes_hair_bald': 0.09, 'faceAttributes_hair_invisible': False, 'faceAttributes_hair_hairColor_0_color': 'black', 'faceAttributes_hair_hairColor_0_confidence': 0.98, 'faceAttributes_hair_hairColor_1_color': 'brown', 'faceAttributes_hair_hairColor_1_confidence': 0.95, 'faceAttributes_hair_hairColor_2_color': 'gray', 'faceAttributes_hair_hairColor_2_confidence': 0.59, 'faceAttributes_hair_hairColor_3_color': 'other', 'faceAttributes_hair_hairColor_3_confidence': 0.23, 'faceAttributes_hair_hairColor_4_color': 'red', 'faceAttributes_hair_hairColor_4_confidence': 0.05, 'faceAttributes_hair_hairColor_5_color': 'blond', 'faceAttributes_hair_hairColor_5_confidence': 0.05}
# {'faceId': '0f4d6ed5-cea9-43b3-b5db-7adddcd4056c', 'faceRectangle_top': 41, 'faceRectangle_left': 30, 'faceRectangle_width': 67, 'faceRectangle_height': 67, 'faceAttributes_smile': 1.0, 'faceAttributes_headPose_pitch': -16.4, 'faceAttributes_headPose_roll': 2.3, 'faceAttributes_headPose_yaw': 1.9, 'faceAttributes_gender': 'male', 'faceAttributes_age': 3.0, 'faceAttributes_facialHair_moustache': 0.0, 'faceAttributes_facialHair_beard': 0.0, 'faceAttributes_facialHair_sideburns': 0.0, 'faceAttributes_glasses': 'NoGlasses', 'faceAttributes_emotion_anger': 0.0, 'faceAttributes_emotion_contempt': 0.0, 'faceAttributes_emotion_disgust': 0.0, 'faceAttributes_emotion_fear': 0.0, 'faceAttributes_emotion_happiness': 1.0, 'faceAttributes_emotion_neutral': 0.0, 'faceAttributes_emotion_sadness': 0.0, 'faceAttributes_emotion_surprise': 0.0, 'faceAttributes_blur_blurLevel': 'low', 'faceAttributes_blur_value': 0.08, 'faceAttributes_exposure_exposureLevel': 'goodExposure', 'faceAttributes_exposure_value': 0.64, 'faceAttributes_noise_noiseLevel': 'low', 'faceAttributes_noise_value': 0.09, 'faceAttributes_makeup_eyeMakeup': False, 'faceAttributes_makeup_lipMakeup': False, 'faceAttributes_occlusion_foreheadOccluded': False, 'faceAttributes_occlusion_eyeOccluded': False, 'faceAttributes_occlusion_mouthOccluded': False, 'faceAttributes_hair_bald': 0.04, 'faceAttributes_hair_invisible': False, 'faceAttributes_hair_hairColor_0_color': 'brown', 'faceAttributes_hair_hairColor_0_confidence': 0.99, 'faceAttributes_hair_hairColor_1_color': 'blond', 'faceAttributes_hair_hairColor_1_confidence': 0.68, 'faceAttributes_hair_hairColor_2_color': 'black', 'faceAttributes_hair_hairColor_2_confidence': 0.51, 'faceAttributes_hair_hairColor_3_color': 'red', 'faceAttributes_hair_hairColor_3_confidence': 0.25, 'faceAttributes_hair_hairColor_4_color': 'gray', 'faceAttributes_hair_hairColor_4_confidence': 0.16, 'faceAttributes_hair_hairColor_5_color': 'other', 'faceAttributes_hair_hairColor_5_confidence': 0.08}
