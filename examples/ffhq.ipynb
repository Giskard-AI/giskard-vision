# %%
from loreal_poc.dataloaders.loaders import DataLoaderFFHQ

dl = DataLoaderFFHQ("ffhq")

# %%
image, marks, meta = dl[0]

from loreal_poc.visualisation.draw import draw_marks

draw_marks(image, [marks], ["green"])
# Out:
# <PIL.Image.Image image mode=RGB size=1024x1024>

# %%
for _, _, meta in dl:
    print(meta["faceAttributes"]["headPose"])
# Out:
# {'pitch': 5.4, 'roll': 1.5, 'yaw': 15.3}
# {'pitch': -7.3, 'roll': -0.8, 'yaw': -0.3}
# {'pitch': -4.6, 'roll': 2.4, 'yaw': 6.1}
# {'pitch': -2.4, 'roll': 0.9, 'yaw': 4.1}
# {'pitch': -7.7, 'roll': 0.0, 'yaw': -4.5}
